# %% [markdown]
# ## GrabCut then detect cat face

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import csv

def grab(image):

    img = cv2.imread(image)
    
    mask = np.full(img.shape[:2],0,np.uint8)
    bgdModel = np.zeros((1,65),np.float64)
    fgdModel = np.zeros((1,65),np.float64)
    
    rect = (int(img.shape[0]*0.1),int(img.shape[1]*0.1),int(img.shape[0]*0.9),int(img.shape[1]*0.9))
    cv2.grabCut(img,mask,rect,bgdModel,fgdModel,1,cv2.GC_INIT_WITH_RECT)
    mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    img = img*mask2[:,:,np.newaxis]
    
#     test for cat detection using OpenCV pretrained classifier
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)     
#     faces = face_cascade.detectMultiScale(gray, 1.3, minNeighbors=5, minSize=(25, 25))
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
    return img

def getFeatures(img, catDescriptors, dogDescriptors, dog):
    sift = cv2.xfeatures2d.SIFT_create()
    kp, des = sift.detectAndCompute(img,None)
    if (dog):
        dogDescriptors.append(des)
    else:
        catDescriptors.append(des)

trainDir = 'X_Train'
with open('Y_Train.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in reader:
        print(', '.join(row))

# df = pd.read_csv('Y_Train.csv')
# images = df.Image #you can also use df['column_name']
# labels = df.Label
# dog = 0

for i in range(10):
    img = cv2.imread(trainDir + "/" + images[i])
    dog = 0
    if (labels[i] == 1):
        dog = 1
    img = grab(img)
    
    catDescriptors = []
    dogDescriptors = []
    
    getFeatures(img, catDescriptors, dogDescriptors, dog)
    
    plt.imshow(img),plt.title('Dog' if dog == 1 else 'Cat'),plt.show()

# face_cascade = cv2.CascadeClassifier('haarcascade/haarcascade_frontalcatface.xml')

# for subdir, dirs, files in os.walk(rootdir):

#     for file in files:
#         img = grabAndDetect(rootdir + '/' + file)
#         plt.imshow(img);plt.title(file)
#         plt.show()
# Out:
# Image,Label
# 0.jpg,1
# 1.jpg,1
# 2.jpg,0
# 3.jpg,0
# 4.jpg,0
# 5.jpg,1
# 6.jpg,1
# 7.jpg,0
# 8.jpg,1
# 9.jpg,1
# 10.jpg,0
# 11.jpg,0
# 12.jpg,1
# 13.jpg,1
# 14.jpg,0
# 15.jpg,0
# 16.jpg,1
# 17.jpg,1
# 18.jpg,0
# 19.jpg,1
# 20.jpg,0
# 21.jpg,1
# 22.jpg,0
# 23.jpg,1
# 24.jpg,0
# 25.jpg,1
# 26.jpg,0
# 27.jpg,0
# 28.jpg,0
# 29.jpg,0
# 30.jpg,1
# 31.jpg,0
# 32.jpg,1
# 33.jpg,1
# 34.jpg,0
# 35.jpg,1
# 36.jpg,1
# 37.jpg,1
# 38.jpg,1
# 39.jpg,1
# 40.jpg,1
# 41.jpg,0
# 42.jpg,1
# 43.jpg,1
# 44.jpg,1
# 45.jpg,1
# 46.jpg,1
# 47.jpg,1
# 48.jpg,1
# 49.jpg,0
# 50.jpg,0
# 51.jpg,1
# 52.jpg,0
# 53.jpg,1
# 54.jpg,0
# 55.jpg,1
# 56.jpg,0
# 57.jpg,1
# 58.jpg,1
# 59.jpg,1
# 60.jpg,1
# 61.jpg,0
# 62.jpg,0
# 63.jpg,1
# 64.jpg,1
# 65.jpg,1
# 66.jpg,1
# 67.jpg,0
# 68.jpg,1
# 69.jpg,0
# 70.jpg,0
# 71.jpg,1
# 72.jpg,0
# 73.jpg,0
# 74.jpg,1
# 75.jpg,0
# 76.jpg,1
# 77.jpg,1
# 78.jpg,0
# 79.jpg,1
# 80.jpg,0
# 81.jpg,1
# 82.jpg,1
# 83.jpg,1
# 84.jpg,1
# 85.jpg,0
# 86.jpg,1
# 87.jpg,1
# 88.jpg,1
# 89.jpg,1
# ...
